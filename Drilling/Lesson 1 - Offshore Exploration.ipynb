# %% [markdown]
# <a href="https://colab.research.google.com/github/Mechtanium/.alx-automation/blob/main/Drilling/Lesson%201%20-%20Offshore%20Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Setup
from IPython.display import YouTubeVideo as yt, HTML as web

# %% [markdown]
# # **Introduction to Offshore**
#
# The life of an offshore operation may be casually delineated into three broad parts. Exploration, Drilling and Production. In this notebook we will cover each of these phases with a focus on the procedures performed and the equipment used.
#
# | Phase         | Procedures | Equipment  |
# |---------------|------------|------------|
# | Exploration   |◯          |◯          |
# | Drilling      |◯          |◯          |
# | Production    |◯          |◯          |
#
# But first, let's take a look at the context in which offshore oil & gas wells sit within the industry.

# %%
# @title [Video] How to decide between offshore and onshore wells

yt('ABIkWS_YavM', width="280", height="158")

# %% [markdown]
# Offshore
# When the economics determine that its feasible to drill an offshore well, we can then begin to explore the chosen area.

# %% [markdown]
# ## **Exploration**
#
# ### How to explore offshore
#
# In exploring offshore, the following steps come to mind
# 1. **Acquire seismic data.** This is done by towing a seismic survey vessel behind a seismic source, which emits sound waves that travel through the water and into the subsurface. The seismic waves are reflected and refracted by different rock layers, and the reflected and refracted waves are detected by hydrophones towed behind the vessel. The seismic data is then processed to create an image of the subsurface geology.
# 2. **Identify potential drilling targets.** The seismic data is analyzed to identify areas where there is a high probability of finding oil or gas. These areas are known as prospects.
# 3. **Assess the risks and rewards of drilling each prospect.** This includes estimating the potential oil or gas reserves, the cost of drilling, and the environmental risks.
# 4. **Obtain the necessary permits and licenses from the government.**

# %% [markdown]
# ### How to acquire and process seismic data
# > [Steps in a seismic survey](https://g.co/bard/share/da083594ced3) <br>
# [Equipment 1: Seismic airguns](https://g.co/bard/share/408a6a481c13) <br>
# [Equipment 2: Seismic hydrophones](https://g.co/bard/share/4be6fb145fb2) <br>
# [Equipment 3: Petrel (3D mapping)](https://youtu.be/mVYbY26mAII?list=PLX8cYDJmWL1mkcLwNRq1nwhQySFTTSz6g) <br>
# [[Quiz] Seismic survey - Attempt all questions](https://classroom.google.com/c/NjMwMTYxOTk1MTQx/a/NjMxMzcwMDE5OTIw/details))

# %%
# @title ##### *Suggested study*

# %%html
<!DOCTYPE html>
<html>
<head>
  <style>
    .grid-container {
        display: grid;
        grid-template-columns: repeat(3, 1fr); /* 3 columns */
        grid-template-rows: repeat(2, 1fr); /* 2 rows */
        gap: 5px; /* Adjust the gap between videos */
    }

    .video {
        position: relative;
        padding-bottom: 56.25%; /* Maintain the video aspect ratio (16:9) */
        overflow: hidden;
    }

    .video iframe {
        position: absolute;
        top: 0;
        left: 0;
        width: 100%;
        height: 100%;
    }
  </style>
</head>
<body>
  <div class="grid-container">
    <div class="video">
      <iframe src="https://www.youtube.com/embed/FN8IAb0rG9A?si=BSodBq5cdqCxI_mv" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
    </div>
    <div class="video">
      <iframe src="https://www.youtube.com/embed/22m27MhzSQs?si=BOetUZ6MjprLq8Cw" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
    </div>
    <div class="video">
      <iframe src="https://www.youtube.com/embed/qcBOZAmgzlc?si=cHn4oMq9Xb5Xw_Sg" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
    </div>
    <div class="video">
      <iframe src="https://www.youtube.com/embed/videoseries?si=1d4JJ23C5IhkiBZB&amp;list=PLX8cYDJmWL1mkcLwNRq1nwhQySFTTSz6g" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
    </div>
    <div class="video">
      <iframe src="https://www.youtube.com/embed/videoseries?si=4d0PJR_FTTh_LPHL&amp;list=PL92NIqfZ7QJYwpUN9dtkkrPJjrD4O2WVW" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
    </div>
    <div class="video">
      <iframe src="https://www.youtube.com/embed/videoseries?si=WADH5KHhifG4mZiq&amp;list=PLR68MbnnoTihvYp_3z5sQnN2vfWAslQlb" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
    </div>
  </div>
</body>
</html>
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <style>
#     .grid-container {
#         display: grid;
#         grid-template-columns: repeat(3, 1fr); /* 3 columns */
#         grid-template-rows: repeat(2, 1fr); /* 2 rows */
#         gap: 5px; /* Adjust the gap between videos */
#     }
#
#     .video {
#         position: relative;
#         padding-bottom: 56.25%; /* Maintain the video aspect ratio (16:9) */
#         overflow: hidden;
#     }
#
#     .video iframe {
#         position: absolute;
#         top: 0;
#         left: 0;
#         width: 100%;
#         height: 100%;
#     }
#   </style>
# </head>
# <body>
#   <div class="grid-container">
#     <div class="video">
#       <iframe src="https://www.youtube.com/embed/FN8IAb0rG9A?si=BSodBq5cdqCxI_mv" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
#     <div class="video">
# ...

# %% [markdown]
# ### How to identify potential drilling targets in a seismic map

# %%
# @title ##### How to interprete seismic profile
# @markdown ```Watch until lesson 5 at least``` <br>
# @markdown [[Assignment] Seismic profiles](https://classroom.google.com/c/NjMwMTYxOTk1MTQx/a/NjMxNjM3NjY3MTY1/details)

# %%html
<iframe width="280" height="156" src="https://www.youtube.com/embed/videoseries?si=LE0PR7XbKEkA7Nne&amp;list=PLxvNbEa7Qws59ACzCgFD-DMGEDR8xpt7f" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
# Out:
# <iframe width="280" height="156" src="https://www.youtube.com/embed/videoseries?si=LE0PR7XbKEkA7Nne&amp;list=PLxvNbEa7Qws59ACzCgFD-DMGEDR8xpt7f" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>

# %% [markdown]
# ### How to assess risk and economics of an offshore prospect

# %%
# %%html
# <iframe width="280" height="156" src="https://www.youtube.com/embed/CO8LDV2sO6M?si=LHiWzWhHeDoRW6cO" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
# Out:
# <iframe width="280" height="156" src="https://www.youtube.com/embed/CO8LDV2sO6M?si=LHiWzWhHeDoRW6cO" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>

# %% [markdown]
# ### How to acquire oil and gas licenses and permits in Nigeria
#
# The [Petroleum Industry Act - 2021](http://www.petroleumindustrybill.com/wp-content/uploads/2021/09/Official-Gazette-of-the-Petroleum-Industry-Act-2021.pdf) specifies the 3 kinds of petroleum licenses that can be acquired.
#
# > Refer to [PIA • sections 70 (Licenses and leases) - 89 (Surrender of license or lease)](http://www.petroleumindustrybill.com/wp-content/uploads/2021/09/Official-Gazette-of-the-Petroleum-Industry-Act-2021.pdf#page=58) <br>
# [[Quiz] All about PIA licenses - Attempt all questions]()
